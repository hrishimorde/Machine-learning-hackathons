# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'whitegrid')

import os
path = os.getcwd()
data_path = 'C:\\Users\\sunil\\Projects\\Dockship\\Exam Mark Prediction\\Dataset'
sub_path = 'C:\\Users\\sunil\\Projects\\Dockship\\Exam Mark Prediction\\Submissions'

#### Preprocessing ####
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, LeaveOneOut

le = LabelEncoder()
scaler = MinMaxScaler()

#### Models ####
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor, BaggingRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.svm import SVR

###
import lightgbm as lgbm

#### Evaluation ####
from sklearn.metrics import mean_squared_error

# %%
train = pd.read_csv(data_path+ '\\train.csv')
test = pd.read_csv(data_path+ '\\test.csv')
sample_sub = pd.read_csv(data_path+ '\\sample_submissions.csv')

# %%
train.drop('Unnamed: 0', axis = 1, inplace=True)
test.drop('Unnamed: 0', axis = 1, inplace=True)

# %% [markdown]
# ---
# # Preprocessing

# %%
df = pd.concat([train, test], axis = 0).reset_index(drop=True)

# %%
cat_cols = ['gender', 'ethnicity', 'parental level of education', 'lunch',
       'test preparation course', ]

num_cols = ['reading score', 'writing score']

# %%
#df[cat_cols] = df[cat_cols].apply(le.fit_transform)

df = pd.get_dummies(data=df, columns=cat_cols, drop_first=True)

# %%
import re
df = df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
train_proc, test_proc = df[:train.shape[0]], df[train.shape[0]:].reset_index(drop=True)

features = [col for col in test_proc.columns if col not in [target]]

# %%
features
# Out:
# ['readingscore',
#  'writingscore',
#  'mathscore',
#  'gender_male',
#  'ethnicity_groupB',
#  'ethnicity_groupC',
#  'ethnicity_groupD',
#  'ethnicity_groupE',
#  'parentallevelofeducation_bachelorsdegree',
#  'parentallevelofeducation_highschool',
#  'parentallevelofeducation_mastersdegree',
#  'parentallevelofeducation_somecollege',
#  'parentallevelofeducation_somehighschool',
#  'lunch_standard',
#  'testpreparationcourse_none']

# %%
y = train_proc['mathscore']
kf = KFold(n_splits=5, shuffle=True, random_state=1)
oof = np.zeros(len(train))
score_list = []
fold = 1
test_preds = []
seed_list = [None,2,3]# Use more. Original list: [None,2,3,4,5]


for train_index, test_index in kf.split(train):
    X_train, X_val = train_proc.iloc[train_index], train_proc.iloc[test_index]
    y_train, y_val = y.iloc[train_index], y.iloc[test_index]
    
    

    #X_train = X_train.abs() # Taking aboslute was also a bit improving.

    y_pred_list = []
    for seed in seed_list:
        dtrain = lgbm.Dataset(X_train[features], y_train)
        dvalid = lgbm.Dataset(X_val[features], y_val)
        print(seed)
        params = {"objective": "regression",
              "metric": "rmse",
              "verbosity": -1,
              "boosting_type": "gbdt",
              "feature_fraction":0.5,
              "num_leaves": 250,
              #"lambda_l1":7,
              #"lambda_l2":2,
              "learning_rate":0.01,
              'min_child_samples': 35,
              "bagging_fraction":0.75,
              "bagging_freq":1,
             }
        params["seed"] = seed
        model = lgbm.train(params,
                        dtrain,
                        valid_sets=[dtrain, dvalid],
                        verbose_eval=100,
                        num_boost_round=100000,
                        early_stopping_rounds=50
                    )

        dtrain = lgbm.Dataset(X_train[features], y_train)
        dvalid = lgbm.Dataset(X_val[features], y_val)
        params = {"objective": "regression",
                  "metric": "rmse",
                  "verbosity": -1,
                  "boosting_type": "gbdt",
                  "feature_fraction":0.5,
                  "num_leaves": 350,
                  #"lambda_l1":7,
                  #"lambda_l2":1,
                  "learning_rate":0.003,
                  'min_child_samples': 35,
                  "bagging_fraction":0.8,
                  "bagging_freq":1,
                 }
        
        params["seed"] = seed
        model = lgbm.train(params,
                            dtrain,
                            valid_sets=[dtrain, dvalid],
                            verbose_eval=100,
                            num_boost_round=100000,
                            early_stopping_rounds=50,
                           init_model = model
                        )

    
    
        y_pred_list.append(model.predict(X_val[features]))
        print(np.sqrt(mean_squared_error(y_val,   np.mean(y_pred_list,axis=0)       )))
        test_preds.append(model.predict(test_proc[features]))
        
    
   
    
    oof[test_index] = np.mean(y_pred_list,axis=0)    
    score = np.sqrt(mean_squared_error(y_val, oof[test_index]))
    score_list.append(score)
    print(f"RMSE Fold-{fold} : {score}")
    fold+=1

np.mean(score_list)
# Out:
# None
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.46697	valid_1's rmse: 7.4525
# [200]	training's rmse: 4.33267	valid_1's rmse: 4.59473
# [300]	training's rmse: 3.10659	valid_1's rmse: 3.45247
# [400]	training's rmse: 2.66775	valid_1's rmse: 3.00665
# [500]	training's rmse: 2.49275	valid_1's rmse: 2.81761
# [600]	training's rmse: 2.38382	valid_1's rmse: 2.70347
# [700]	training's rmse: 2.32302	valid_1's rmse: 2.64326
# [800]	training's rmse: 2.26881	valid_1's rmse: 2.59157
# [900]	training's rmse: 2.22248	valid_1's rmse: 2.55031
# [1000]	training's rmse: 2.17849	valid_1's rmse: 2.50387
# [1100]	training's rmse: 2.13822	valid_1's rmse: 2.46588
# [1200]	training's rmse: 2.10477	valid_1's rmse: 2.43477
# [1300]	training's rmse: 2.07389	valid_1's rmse: 2.40192
# [1400]	training's rmse: 2.04646	valid_1's rmse: 2.38113
# [1500]	training's rmse: 2.01903	valid_1's rmse: 2.3576
# [1600]	training's rmse: 1.99741	valid_1's rmse: 2.34005
# [1700]	training's rmse: 1.97432	valid_1's rmse: 2.31931
# [1800]	training's rmse: 1.95408	valid_1's rmse: 2.30093
# [1900]	training's rmse: 1.93327	valid_1's rmse: 2.27939
# [2000]	training's rmse: 1.91717	valid_1's rmse: 2.26646
# [2100]	training's rmse: 1.89962	valid_1's rmse: 2.24708
# [2200]	training's rmse: 1.88516	valid_1's rmse: 2.24331
# [2300]	training's rmse: 1.8707	valid_1's rmse: 2.22982
# [2400]	training's rmse: 1.85709	valid_1's rmse: 2.22054
# [2500]	training's rmse: 1.84257	valid_1's rmse: 2.20894
# [2600]	training's rmse: 1.82956	valid_1's rmse: 2.19632
# [2700]	training's rmse: 1.81634	valid_1's rmse: 2.1816
# [2800]	training's rmse: 1.80435	valid_1's rmse: 2.17105
# Early stopping, best iteration is:
# [2847]	training's rmse: 1.79883	valid_1's rmse: 2.16734
# Training until validation scores don't improve for 50 rounds
# [2900]	training's rmse: 1.79576	valid_1's rmse: 2.16599
# [3000]	training's rmse: 1.7913	valid_1's rmse: 2.1622
# [3100]	training's rmse: 1.78596	valid_1's rmse: 2.15803
# [3200]	training's rmse: 1.78028	valid_1's rmse: 2.15251
# [3300]	training's rmse: 1.77573	valid_1's rmse: 2.1508
# [3400]	training's rmse: 1.77082	valid_1's rmse: 2.14804
# [3500]	training's rmse: 1.76643	valid_1's rmse: 2.14423
# [3600]	training's rmse: 1.76236	valid_1's rmse: 2.14128
# [3700]	training's rmse: 1.75875	valid_1's rmse: 2.13719
# [3800]	training's rmse: 1.75446	valid_1's rmse: 2.13341
# [3900]	training's rmse: 1.7502	valid_1's rmse: 2.1301
# [4000]	training's rmse: 1.74606	valid_1's rmse: 2.1263
# [4100]	training's rmse: 1.74209	valid_1's rmse: 2.12365
# [4200]	training's rmse: 1.73761	valid_1's rmse: 2.12024
# Early stopping, best iteration is:
# [4230]	training's rmse: 1.73618	valid_1's rmse: 2.11921
# 2.1192131878347067
# 2
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.36244	valid_1's rmse: 7.38077
# [200]	training's rmse: 4.25556	valid_1's rmse: 4.57191
# [300]	training's rmse: 3.11652	valid_1's rmse: 3.52216
# [400]	training's rmse: 2.71179	valid_1's rmse: 3.09879
# [500]	training's rmse: 2.50878	valid_1's rmse: 2.87845
# [600]	training's rmse: 2.41138	valid_1's rmse: 2.77173
# [700]	training's rmse: 2.3415	valid_1's rmse: 2.70427
# [800]	training's rmse: 2.28497	valid_1's rmse: 2.6557
# [900]	training's rmse: 2.23657	valid_1's rmse: 2.6009
# [1000]	training's rmse: 2.19285	valid_1's rmse: 2.56273
# [1100]	training's rmse: 2.15499	valid_1's rmse: 2.53649
# [1200]	training's rmse: 2.11924	valid_1's rmse: 2.50364
# [1300]	training's rmse: 2.08415	valid_1's rmse: 2.46559
# [1400]	training's rmse: 2.05855	valid_1's rmse: 2.44101
# [1500]	training's rmse: 2.03135	valid_1's rmse: 2.4134
# [1600]	training's rmse: 2.00836	valid_1's rmse: 2.40015
# [1700]	training's rmse: 1.98603	valid_1's rmse: 2.37769
# [1800]	training's rmse: 1.9648	valid_1's rmse: 2.3661
# [1900]	training's rmse: 1.94529	valid_1's rmse: 2.34375
# [2000]	training's rmse: 1.92461	valid_1's rmse: 2.32117
# [2100]	training's rmse: 1.90686	valid_1's rmse: 2.30803
# [2200]	training's rmse: 1.8892	valid_1's rmse: 2.2907
# [2300]	training's rmse: 1.87474	valid_1's rmse: 2.27928
# [2400]	training's rmse: 1.86065	valid_1's rmse: 2.26851
# [2500]	training's rmse: 1.84654	valid_1's rmse: 2.26084
# [2600]	training's rmse: 1.83273	valid_1's rmse: 2.24538
# [2700]	training's rmse: 1.81963	valid_1's rmse: 2.22939
# [2800]	training's rmse: 1.8088	valid_1's rmse: 2.21259
# Early stopping, best iteration is:
# [2843]	training's rmse: 1.80258	valid_1's rmse: 2.20709
# Training until validation scores don't improve for 50 rounds
# [2900]	training's rmse: 1.79929	valid_1's rmse: 2.20461
# [3000]	training's rmse: 1.79451	valid_1's rmse: 2.20068
# [3100]	training's rmse: 1.78989	valid_1's rmse: 2.19843
# [3200]	training's rmse: 1.785	valid_1's rmse: 2.19527
# [3300]	training's rmse: 1.78012	valid_1's rmse: 2.19173
# [3400]	training's rmse: 1.77545	valid_1's rmse: 2.18819
# [3500]	training's rmse: 1.77137	valid_1's rmse: 2.18465
# [3600]	training's rmse: 1.76697	valid_1's rmse: 2.18312
# [3700]	training's rmse: 1.76319	valid_1's rmse: 2.17986
# [3800]	training's rmse: 1.75936	valid_1's rmse: 2.17788
# [3900]	training's rmse: 1.75516	valid_1's rmse: 2.17492
# [4000]	training's rmse: 1.75102	valid_1's rmse: 2.1724
# [4100]	training's rmse: 1.74645	valid_1's rmse: 2.16881
# [4200]	training's rmse: 1.74247	valid_1's rmse: 2.16625
# [4300]	training's rmse: 1.73816	valid_1's rmse: 2.16323
# [4400]	training's rmse: 1.73443	valid_1's rmse: 2.16064
# [4500]	training's rmse: 1.72995	valid_1's rmse: 2.15819
# [4600]	training's rmse: 1.72619	valid_1's rmse: 2.15624
# [4700]	training's rmse: 1.72207	valid_1's rmse: 2.15264
# [4800]	training's rmse: 1.71827	valid_1's rmse: 2.15004
# [4900]	training's rmse: 1.71445	valid_1's rmse: 2.14701
# [5000]	training's rmse: 1.71027	valid_1's rmse: 2.14447
# [5100]	training's rmse: 1.70673	valid_1's rmse: 2.14102
# [5200]	training's rmse: 1.70331	valid_1's rmse: 2.13837
# [5300]	training's rmse: 1.69991	valid_1's rmse: 2.13598
# [5400]	training's rmse: 1.69616	valid_1's rmse: 2.13449
# [5500]	training's rmse: 1.69295	valid_1's rmse: 2.13245
# [5600]	training's rmse: 1.68982	valid_1's rmse: 2.12886
# [5700]	training's rmse: 1.68643	valid_1's rmse: 2.1276
# Early stopping, best iteration is:
# [5673]	training's rmse: 1.68713	valid_1's rmse: 2.12704
# 2.121330692982301
# 3
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.21562	valid_1's rmse: 7.25064
# [200]	training's rmse: 4.03865	valid_1's rmse: 4.37488
# [300]	training's rmse: 2.93343	valid_1's rmse: 3.32437
# [400]	training's rmse: 2.58596	valid_1's rmse: 2.95283
# [500]	training's rmse: 2.43627	valid_1's rmse: 2.77653
# [600]	training's rmse: 2.34745	valid_1's rmse: 2.67013
# [700]	training's rmse: 2.28332	valid_1's rmse: 2.6027
# [800]	training's rmse: 2.23365	valid_1's rmse: 2.5506
# [900]	training's rmse: 2.19385	valid_1's rmse: 2.52139
# [1000]	training's rmse: 2.15248	valid_1's rmse: 2.47959
# [1100]	training's rmse: 2.1228	valid_1's rmse: 2.4593
# [1200]	training's rmse: 2.09072	valid_1's rmse: 2.42621
# [1300]	training's rmse: 2.06339	valid_1's rmse: 2.40495
# [1400]	training's rmse: 2.03787	valid_1's rmse: 2.38207
# [1500]	training's rmse: 2.01151	valid_1's rmse: 2.35348
# [1600]	training's rmse: 1.98773	valid_1's rmse: 2.33434
# [1700]	training's rmse: 1.96613	valid_1's rmse: 2.31565
# Early stopping, best iteration is:
# [1722]	training's rmse: 1.96085	valid_1's rmse: 2.30684
# Training until validation scores don't improve for 50 rounds
# [1800]	training's rmse: 1.95457	valid_1's rmse: 2.30129
# [1900]	training's rmse: 1.94703	valid_1's rmse: 2.29756
# [2000]	training's rmse: 1.93983	valid_1's rmse: 2.2911
# [2100]	training's rmse: 1.93193	valid_1's rmse: 2.28562
# [2200]	training's rmse: 1.92499	valid_1's rmse: 2.2788
# [2300]	training's rmse: 1.91821	valid_1's rmse: 2.27334
# [2400]	training's rmse: 1.91153	valid_1's rmse: 2.26794
# [2500]	training's rmse: 1.9046	valid_1's rmse: 2.2604
# [2600]	training's rmse: 1.89832	valid_1's rmse: 2.25521
# [2700]	training's rmse: 1.89109	valid_1's rmse: 2.24766
# [2800]	training's rmse: 1.88505	valid_1's rmse: 2.24234
# [2900]	training's rmse: 1.87919	valid_1's rmse: 2.23677
# [3000]	training's rmse: 1.87259	valid_1's rmse: 2.23194
# [3100]	training's rmse: 1.86646	valid_1's rmse: 2.22738
# [3200]	training's rmse: 1.86019	valid_1's rmse: 2.22067
# [3300]	training's rmse: 1.85428	valid_1's rmse: 2.2159
# [3400]	training's rmse: 1.84831	valid_1's rmse: 2.21125
# Early stopping, best iteration is:
# [3444]	training's rmse: 1.84523	valid_1's rmse: 2.20748
# 2.146763389858425
# RMSE Fold-1 : 2.146763389858425
# None
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.34865	valid_1's rmse: 8.03401
# [200]	training's rmse: 4.2424	valid_1's rmse: 5.05871
# [300]	training's rmse: 3.03871	valid_1's rmse: 3.87668
# [400]	training's rmse: 2.6024	valid_1's rmse: 3.42776
# [500]	training's rmse: 2.42737	valid_1's rmse: 3.24251
# [600]	training's rmse: 2.32231	valid_1's rmse: 3.13908
# [700]	training's rmse: 2.25443	valid_1's rmse: 3.07991
# [800]	training's rmse: 2.19973	valid_1's rmse: 3.03752
# [900]	training's rmse: 2.15112	valid_1's rmse: 2.99948
# [1000]	training's rmse: 2.10965	valid_1's rmse: 2.96402
# [1100]	training's rmse: 2.0708	valid_1's rmse: 2.93615
# [1200]	training's rmse: 2.03963	valid_1's rmse: 2.91077
# [1300]	training's rmse: 2.01126	valid_1's rmse: 2.88796
# [1400]	training's rmse: 1.98434	valid_1's rmse: 2.86689
# [1500]	training's rmse: 1.95612	valid_1's rmse: 2.84252
# [1600]	training's rmse: 1.93077	valid_1's rmse: 2.81667
# [1700]	training's rmse: 1.90947	valid_1's rmse: 2.79898
# [1800]	training's rmse: 1.88968	valid_1's rmse: 2.78252
# [1900]	training's rmse: 1.87096	valid_1's rmse: 2.7641
# [2000]	training's rmse: 1.855	valid_1's rmse: 2.7495
# [2100]	training's rmse: 1.83772	valid_1's rmse: 2.73393
# [2200]	training's rmse: 1.82367	valid_1's rmse: 2.72384
# [2300]	training's rmse: 1.81018	valid_1's rmse: 2.71323
# [2400]	training's rmse: 1.79655	valid_1's rmse: 2.70363
# [2500]	training's rmse: 1.78529	valid_1's rmse: 2.69135
# [2600]	training's rmse: 1.77387	valid_1's rmse: 2.68267
# [2700]	training's rmse: 1.76252	valid_1's rmse: 2.67285
# [2800]	training's rmse: 1.74916	valid_1's rmse: 2.66008
# [2900]	training's rmse: 1.73884	valid_1's rmse: 2.65057
# [3000]	training's rmse: 1.72831	valid_1's rmse: 2.64171
# [3100]	training's rmse: 1.71783	valid_1's rmse: 2.62894
# [3200]	training's rmse: 1.70919	valid_1's rmse: 2.6248
# [3300]	training's rmse: 1.69943	valid_1's rmse: 2.61736
# [3400]	training's rmse: 1.69161	valid_1's rmse: 2.61315
# [3500]	training's rmse: 1.68216	valid_1's rmse: 2.6059
# [3600]	training's rmse: 1.6726	valid_1's rmse: 2.59611
# [3700]	training's rmse: 1.66595	valid_1's rmse: 2.59251
# [3800]	training's rmse: 1.6579	valid_1's rmse: 2.58723
# [3900]	training's rmse: 1.65074	valid_1's rmse: 2.58349
# [4000]	training's rmse: 1.64354	valid_1's rmse: 2.57823
# [4100]	training's rmse: 1.63696	valid_1's rmse: 2.57373
# [4200]	training's rmse: 1.62918	valid_1's rmse: 2.56878
# [4300]	training's rmse: 1.62248	valid_1's rmse: 2.5641
# [4400]	training's rmse: 1.61611	valid_1's rmse: 2.55872
# [4500]	training's rmse: 1.6086	valid_1's rmse: 2.54891
# [4600]	training's rmse: 1.60255	valid_1's rmse: 2.54276
# Early stopping, best iteration is:
# [4583]	training's rmse: 1.60358	valid_1's rmse: 2.54183
# Training until validation scores don't improve for 50 rounds
# [4600]	training's rmse: 1.6032	valid_1's rmse: 2.54159
# [4700]	training's rmse: 1.60067	valid_1's rmse: 2.54013
# [4800]	training's rmse: 1.598	valid_1's rmse: 2.53925
# [4900]	training's rmse: 1.59542	valid_1's rmse: 2.5375
# [5000]	training's rmse: 1.59304	valid_1's rmse: 2.53556
# [5100]	training's rmse: 1.59074	valid_1's rmse: 2.53398
# [5200]	training's rmse: 1.58802	valid_1's rmse: 2.53185
# [5300]	training's rmse: 1.58598	valid_1's rmse: 2.5306
# [5400]	training's rmse: 1.58383	valid_1's rmse: 2.52986
# [5500]	training's rmse: 1.58162	valid_1's rmse: 2.5273
# [5600]	training's rmse: 1.57945	valid_1's rmse: 2.52549
# [5700]	training's rmse: 1.57743	valid_1's rmse: 2.52499
# [5800]	training's rmse: 1.57534	valid_1's rmse: 2.52298
# [5900]	training's rmse: 1.57328	valid_1's rmse: 2.52095
# [6000]	training's rmse: 1.57113	valid_1's rmse: 2.51946
# [6100]	training's rmse: 1.5688	valid_1's rmse: 2.51731
# [6200]	training's rmse: 1.56664	valid_1's rmse: 2.5159
# [6300]	training's rmse: 1.5646	valid_1's rmse: 2.51475
# [6400]	training's rmse: 1.56238	valid_1's rmse: 2.51211
# [6500]	training's rmse: 1.56027	valid_1's rmse: 2.51035
# [6600]	training's rmse: 1.55832	valid_1's rmse: 2.50906
# [6700]	training's rmse: 1.55604	valid_1's rmse: 2.50782
# [6800]	training's rmse: 1.55409	valid_1's rmse: 2.50723
# [6900]	training's rmse: 1.55217	valid_1's rmse: 2.50645
# [7000]	training's rmse: 1.55032	valid_1's rmse: 2.50492
# [7100]	training's rmse: 1.54863	valid_1's rmse: 2.50405
# [7200]	training's rmse: 1.54686	valid_1's rmse: 2.50287
# [7300]	training's rmse: 1.54512	valid_1's rmse: 2.50215
# [7400]	training's rmse: 1.54321	valid_1's rmse: 2.5001
# [7500]	training's rmse: 1.54119	valid_1's rmse: 2.49845
# [7600]	training's rmse: 1.53924	valid_1's rmse: 2.4967
# [7700]	training's rmse: 1.53752	valid_1's rmse: 2.49548
# [7800]	training's rmse: 1.53546	valid_1's rmse: 2.4945
# [7900]	training's rmse: 1.53348	valid_1's rmse: 2.49245
# [8000]	training's rmse: 1.53166	valid_1's rmse: 2.4915
# [8100]	training's rmse: 1.52948	valid_1's rmse: 2.48964
# [8200]	training's rmse: 1.52731	valid_1's rmse: 2.4876
# [8300]	training's rmse: 1.52561	valid_1's rmse: 2.48676
# Early stopping, best iteration is:
# [8329]	training's rmse: 1.52495	valid_1's rmse: 2.48607
# 2.4860657709602703
# 2
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.24187	valid_1's rmse: 7.85793
# [200]	training's rmse: 4.17319	valid_1's rmse: 4.93501
# [300]	training's rmse: 3.05403	valid_1's rmse: 3.85209
# [400]	training's rmse: 2.64758	valid_1's rmse: 3.43909
# [500]	training's rmse: 2.44324	valid_1's rmse: 3.23351
# [600]	training's rmse: 2.3435	valid_1's rmse: 3.13675
# [700]	training's rmse: 2.27752	valid_1's rmse: 3.08083
# [800]	training's rmse: 2.21816	valid_1's rmse: 3.03209
# [900]	training's rmse: 2.17097	valid_1's rmse: 2.99909
# [1000]	training's rmse: 2.12887	valid_1's rmse: 2.96881
# [1100]	training's rmse: 2.09008	valid_1's rmse: 2.93975
# [1200]	training's rmse: 2.05715	valid_1's rmse: 2.90996
# [1300]	training's rmse: 2.02559	valid_1's rmse: 2.88617
# [1400]	training's rmse: 2.00068	valid_1's rmse: 2.86357
# [1500]	training's rmse: 1.97447	valid_1's rmse: 2.84221
# [1600]	training's rmse: 1.95306	valid_1's rmse: 2.82695
# [1700]	training's rmse: 1.92999	valid_1's rmse: 2.8084
# [1800]	training's rmse: 1.90911	valid_1's rmse: 2.79499
# [1900]	training's rmse: 1.88855	valid_1's rmse: 2.77733
# [2000]	training's rmse: 1.86986	valid_1's rmse: 2.76339
# [2100]	training's rmse: 1.85077	valid_1's rmse: 2.7463
# [2200]	training's rmse: 1.83647	valid_1's rmse: 2.73319
# [2300]	training's rmse: 1.82092	valid_1's rmse: 2.71857
# [2400]	training's rmse: 1.8064	valid_1's rmse: 2.70993
# [2500]	training's rmse: 1.79224	valid_1's rmse: 2.69607
# [2600]	training's rmse: 1.77853	valid_1's rmse: 2.68343
# [2700]	training's rmse: 1.76645	valid_1's rmse: 2.67084
# [2800]	training's rmse: 1.7552	valid_1's rmse: 2.65917
# [2900]	training's rmse: 1.74534	valid_1's rmse: 2.65338
# [3000]	training's rmse: 1.73347	valid_1's rmse: 2.642
# [3100]	training's rmse: 1.72366	valid_1's rmse: 2.63319
# [3200]	training's rmse: 1.71406	valid_1's rmse: 2.62562
# [3300]	training's rmse: 1.70461	valid_1's rmse: 2.61939
# [3400]	training's rmse: 1.69498	valid_1's rmse: 2.61018
# [3500]	training's rmse: 1.68544	valid_1's rmse: 2.60073
# [3600]	training's rmse: 1.67618	valid_1's rmse: 2.59364
# [3700]	training's rmse: 1.6675	valid_1's rmse: 2.58355
# [3800]	training's rmse: 1.66006	valid_1's rmse: 2.57648
# [3900]	training's rmse: 1.65309	valid_1's rmse: 2.57249
# [4000]	training's rmse: 1.64524	valid_1's rmse: 2.5691
# Early stopping, best iteration is:
# [3970]	training's rmse: 1.64759	valid_1's rmse: 2.56833
# Training until validation scores don't improve for 50 rounds
# [4000]	training's rmse: 1.64659	valid_1's rmse: 2.56695
# [4100]	training's rmse: 1.64386	valid_1's rmse: 2.5644
# [4200]	training's rmse: 1.64105	valid_1's rmse: 2.56233
# [4300]	training's rmse: 1.63847	valid_1's rmse: 2.5601
# [4400]	training's rmse: 1.63563	valid_1's rmse: 2.558
# [4500]	training's rmse: 1.63269	valid_1's rmse: 2.55476
# [4600]	training's rmse: 1.62984	valid_1's rmse: 2.55211
# [4700]	training's rmse: 1.62696	valid_1's rmse: 2.54997
# [4800]	training's rmse: 1.62451	valid_1's rmse: 2.54832
# [4900]	training's rmse: 1.622	valid_1's rmse: 2.54724
# [5000]	training's rmse: 1.61969	valid_1's rmse: 2.54556
# [5100]	training's rmse: 1.61699	valid_1's rmse: 2.54341
# [5200]	training's rmse: 1.61443	valid_1's rmse: 2.54125
# [5300]	training's rmse: 1.61195	valid_1's rmse: 2.53936
# [5400]	training's rmse: 1.60955	valid_1's rmse: 2.53679
# [5500]	training's rmse: 1.607	valid_1's rmse: 2.53482
# [5600]	training's rmse: 1.60478	valid_1's rmse: 2.53294
# [5700]	training's rmse: 1.60228	valid_1's rmse: 2.5309
# [5800]	training's rmse: 1.59998	valid_1's rmse: 2.5294
# [5900]	training's rmse: 1.59749	valid_1's rmse: 2.5286
# [6000]	training's rmse: 1.59497	valid_1's rmse: 2.5265
# [6100]	training's rmse: 1.5925	valid_1's rmse: 2.52472
# [6200]	training's rmse: 1.58998	valid_1's rmse: 2.52295
# [6300]	training's rmse: 1.58751	valid_1's rmse: 2.52095
# [6400]	training's rmse: 1.58508	valid_1's rmse: 2.51897
# [6500]	training's rmse: 1.58252	valid_1's rmse: 2.51675
# [6600]	training's rmse: 1.58029	valid_1's rmse: 2.51488
# [6700]	training's rmse: 1.57806	valid_1's rmse: 2.51284
# [6800]	training's rmse: 1.57607	valid_1's rmse: 2.51111
# Early stopping, best iteration is:
# [6799]	training's rmse: 1.57608	valid_1's rmse: 2.51111
# 2.4972848703910446
# 3
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.10494	valid_1's rmse: 7.72637
# [200]	training's rmse: 3.9394	valid_1's rmse: 4.70316
# [300]	training's rmse: 2.8475	valid_1's rmse: 3.66181
# [400]	training's rmse: 2.50015	valid_1's rmse: 3.31599
# [500]	training's rmse: 2.34849	valid_1's rmse: 3.1664
# [600]	training's rmse: 2.25929	valid_1's rmse: 3.0767
# [700]	training's rmse: 2.19531	valid_1's rmse: 3.01762
# [800]	training's rmse: 2.14639	valid_1's rmse: 2.97608
# [900]	training's rmse: 2.10419	valid_1's rmse: 2.94201
# [1000]	training's rmse: 2.0661	valid_1's rmse: 2.9095
# [1100]	training's rmse: 2.03696	valid_1's rmse: 2.88857
# [1200]	training's rmse: 2.00714	valid_1's rmse: 2.86743
# [1300]	training's rmse: 1.98058	valid_1's rmse: 2.84576
# [1400]	training's rmse: 1.95571	valid_1's rmse: 2.82472
# [1500]	training's rmse: 1.9345	valid_1's rmse: 2.80724
# [1600]	training's rmse: 1.91531	valid_1's rmse: 2.78868
# [1700]	training's rmse: 1.89613	valid_1's rmse: 2.77501
# [1800]	training's rmse: 1.87891	valid_1's rmse: 2.76144
# [1900]	training's rmse: 1.85958	valid_1's rmse: 2.74359
# [2000]	training's rmse: 1.84255	valid_1's rmse: 2.72539
# [2100]	training's rmse: 1.82787	valid_1's rmse: 2.71136
# [2200]	training's rmse: 1.81392	valid_1's rmse: 2.70012
# [2300]	training's rmse: 1.79877	valid_1's rmse: 2.68419
# [2400]	training's rmse: 1.78683	valid_1's rmse: 2.67582
# [2500]	training's rmse: 1.77257	valid_1's rmse: 2.6602
# [2600]	training's rmse: 1.76043	valid_1's rmse: 2.65181
# [2700]	training's rmse: 1.74996	valid_1's rmse: 2.64363
# [2800]	training's rmse: 1.73954	valid_1's rmse: 2.63604
# [2900]	training's rmse: 1.72706	valid_1's rmse: 2.62361
# [3000]	training's rmse: 1.7167	valid_1's rmse: 2.61586
# [3100]	training's rmse: 1.70775	valid_1's rmse: 2.61226
# [3200]	training's rmse: 1.69828	valid_1's rmse: 2.60793
# [3300]	training's rmse: 1.69017	valid_1's rmse: 2.5997
# [3400]	training's rmse: 1.67956	valid_1's rmse: 2.59034
# [3500]	training's rmse: 1.67051	valid_1's rmse: 2.58496
# [3600]	training's rmse: 1.66189	valid_1's rmse: 2.57537
# [3700]	training's rmse: 1.65481	valid_1's rmse: 2.57222
# [3800]	training's rmse: 1.64739	valid_1's rmse: 2.56471
# [3900]	training's rmse: 1.63985	valid_1's rmse: 2.55627
# [4000]	training's rmse: 1.63281	valid_1's rmse: 2.5529
# [4100]	training's rmse: 1.62543	valid_1's rmse: 2.54988
# [4200]	training's rmse: 1.61835	valid_1's rmse: 2.545
# [4300]	training's rmse: 1.61229	valid_1's rmse: 2.54122
# [4400]	training's rmse: 1.60589	valid_1's rmse: 2.53595
# [4500]	training's rmse: 1.59874	valid_1's rmse: 2.52931
# [4600]	training's rmse: 1.59169	valid_1's rmse: 2.5251
# [4700]	training's rmse: 1.58554	valid_1's rmse: 2.51986
# [4800]	training's rmse: 1.57953	valid_1's rmse: 2.51643
# Early stopping, best iteration is:
# [4775]	training's rmse: 1.58111	valid_1's rmse: 2.51624
# Training until validation scores don't improve for 50 rounds
# [4800]	training's rmse: 1.58057	valid_1's rmse: 2.51574
# [4900]	training's rmse: 1.57843	valid_1's rmse: 2.51489
# Early stopping, best iteration is:
# [4885]	training's rmse: 1.57875	valid_1's rmse: 2.51481
# 2.5020675803552264
# RMSE Fold-2 : 2.5020675803552264
# None
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 6.97903	valid_1's rmse: 6.92877
# [200]	training's rmse: 4.09637	valid_1's rmse: 3.88835
# [300]	training's rmse: 3.15712	valid_1's rmse: 2.9064
# [400]	training's rmse: 2.82304	valid_1's rmse: 2.58128
# [500]	training's rmse: 2.65913	valid_1's rmse: 2.42773
# [600]	training's rmse: 2.56917	valid_1's rmse: 2.35736
# [700]	training's rmse: 2.49705	valid_1's rmse: 2.31382
# [800]	training's rmse: 2.43648	valid_1's rmse: 2.27335
# [900]	training's rmse: 2.38837	valid_1's rmse: 2.24264
# [1000]	training's rmse: 2.34737	valid_1's rmse: 2.22479
# [1100]	training's rmse: 2.30516	valid_1's rmse: 2.19416
# [1200]	training's rmse: 2.26696	valid_1's rmse: 2.17785
# [1300]	training's rmse: 2.23422	valid_1's rmse: 2.15719
# [1400]	training's rmse: 2.19865	valid_1's rmse: 2.13894
# [1500]	training's rmse: 2.16914	valid_1's rmse: 2.12542
# [1600]	training's rmse: 2.14216	valid_1's rmse: 2.11718
# [1700]	training's rmse: 2.11808	valid_1's rmse: 2.10126
# [1800]	training's rmse: 2.09846	valid_1's rmse: 2.09455
# [1900]	training's rmse: 2.07607	valid_1's rmse: 2.08438
# [2000]	training's rmse: 2.05264	valid_1's rmse: 2.07366
# Early stopping, best iteration is:
# [1975]	training's rmse: 2.05836	valid_1's rmse: 2.07243
# Training until validation scores don't improve for 50 rounds
# [2000]	training's rmse: 2.05593	valid_1's rmse: 2.07045
# [2100]	training's rmse: 2.04723	valid_1's rmse: 2.06675
# [2200]	training's rmse: 2.03961	valid_1's rmse: 2.06386
# [2300]	training's rmse: 2.03136	valid_1's rmse: 2.05794
# [2400]	training's rmse: 2.0238	valid_1's rmse: 2.05483
# [2500]	training's rmse: 2.01634	valid_1's rmse: 2.05345
# Early stopping, best iteration is:
# [2473]	training's rmse: 2.01802	valid_1's rmse: 2.05233
# 2.052328305430215
# 2
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.31444	valid_1's rmse: 7.34882
# [200]	training's rmse: 4.33294	valid_1's rmse: 4.23404
# [300]	training's rmse: 3.24035	valid_1's rmse: 3.06579
# [400]	training's rmse: 2.87982	valid_1's rmse: 2.69655
# [500]	training's rmse: 2.72382	valid_1's rmse: 2.56122
# [600]	training's rmse: 2.61657	valid_1's rmse: 2.46274
# [700]	training's rmse: 2.54091	valid_1's rmse: 2.40579
# [800]	training's rmse: 2.47895	valid_1's rmse: 2.36611
# [900]	training's rmse: 2.42482	valid_1's rmse: 2.32395
# [1000]	training's rmse: 2.37832	valid_1's rmse: 2.29577
# [1100]	training's rmse: 2.33579	valid_1's rmse: 2.26202
# [1200]	training's rmse: 2.29551	valid_1's rmse: 2.22659
# [1300]	training's rmse: 2.2591	valid_1's rmse: 2.2004
# [1400]	training's rmse: 2.22488	valid_1's rmse: 2.17997
# [1500]	training's rmse: 2.19643	valid_1's rmse: 2.16302
# [1600]	training's rmse: 2.16652	valid_1's rmse: 2.14268
# [1700]	training's rmse: 2.13743	valid_1's rmse: 2.11744
# [1800]	training's rmse: 2.1137	valid_1's rmse: 2.10692
# [1900]	training's rmse: 2.08867	valid_1's rmse: 2.09534
# [2000]	training's rmse: 2.06626	valid_1's rmse: 2.08707
# [2100]	training's rmse: 2.04415	valid_1's rmse: 2.0746
# [2200]	training's rmse: 2.02519	valid_1's rmse: 2.06698
# [2300]	training's rmse: 2.00564	valid_1's rmse: 2.06218
# Early stopping, best iteration is:
# [2284]	training's rmse: 2.00907	valid_1's rmse: 2.05912
# Training until validation scores don't improve for 50 rounds
# [2300]	training's rmse: 2.00788	valid_1's rmse: 2.05798
# [2400]	training's rmse: 2.00151	valid_1's rmse: 2.05493
# [2500]	training's rmse: 1.99527	valid_1's rmse: 2.05362
# [2600]	training's rmse: 1.9884	valid_1's rmse: 2.05016
# Early stopping, best iteration is:
# [2640]	training's rmse: 1.98548	valid_1's rmse: 2.04912
# 2.048561780403441
# 3
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.21767	valid_1's rmse: 7.26893
# [200]	training's rmse: 4.29554	valid_1's rmse: 4.16681
# [300]	training's rmse: 3.34206	valid_1's rmse: 3.19688
# [400]	training's rmse: 2.96681	valid_1's rmse: 2.82298
# [500]	training's rmse: 2.77965	valid_1's rmse: 2.63781
# [600]	training's rmse: 2.65736	valid_1's rmse: 2.53186
# [700]	training's rmse: 2.57066	valid_1's rmse: 2.45665
# [800]	training's rmse: 2.4956	valid_1's rmse: 2.40058
# [900]	training's rmse: 2.43649	valid_1's rmse: 2.35489
# [1000]	training's rmse: 2.38478	valid_1's rmse: 2.32222
# [1100]	training's rmse: 2.33816	valid_1's rmse: 2.29607
# [1200]	training's rmse: 2.29433	valid_1's rmse: 2.25574
# [1300]	training's rmse: 2.25737	valid_1's rmse: 2.22893
# [1400]	training's rmse: 2.22074	valid_1's rmse: 2.20566
# [1500]	training's rmse: 2.192	valid_1's rmse: 2.18852
# [1600]	training's rmse: 2.16205	valid_1's rmse: 2.17614
# [1700]	training's rmse: 2.13498	valid_1's rmse: 2.15756
# [1800]	training's rmse: 2.11152	valid_1's rmse: 2.14668
# [1900]	training's rmse: 2.0876	valid_1's rmse: 2.1273
# [2000]	training's rmse: 2.06697	valid_1's rmse: 2.12451
# Early stopping, best iteration is:
# [1969]	training's rmse: 2.07291	valid_1's rmse: 2.12036
# Training until validation scores don't improve for 50 rounds
# [2000]	training's rmse: 2.07027	valid_1's rmse: 2.11858
# [2100]	training's rmse: 2.06049	valid_1's rmse: 2.1129
# [2200]	training's rmse: 2.05167	valid_1's rmse: 2.10705
# [2300]	training's rmse: 2.0436	valid_1's rmse: 2.10451
# [2400]	training's rmse: 2.03621	valid_1's rmse: 2.10056
# [2500]	training's rmse: 2.02805	valid_1's rmse: 2.09588
# [2600]	training's rmse: 2.02031	valid_1's rmse: 2.09283
# [2700]	training's rmse: 2.01249	valid_1's rmse: 2.08925
# [2800]	training's rmse: 2.00478	valid_1's rmse: 2.08315
# [2900]	training's rmse: 1.99764	valid_1's rmse: 2.08047
# Early stopping, best iteration is:
# [2917]	training's rmse: 1.99643	valid_1's rmse: 2.07969
# 2.0570055183503952
# RMSE Fold-3 : 2.0570055183503952
# None
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.46379	valid_1's rmse: 7.39531
# [200]	training's rmse: 4.33229	valid_1's rmse: 4.48255
# [300]	training's rmse: 3.11996	valid_1's rmse: 3.30929
# [400]	training's rmse: 2.70185	valid_1's rmse: 2.86381
# [500]	training's rmse: 2.53521	valid_1's rmse: 2.67558
# [600]	training's rmse: 2.43722	valid_1's rmse: 2.56033
# [700]	training's rmse: 2.37184	valid_1's rmse: 2.49586
# [800]	training's rmse: 2.32088	valid_1's rmse: 2.44009
# [900]	training's rmse: 2.27529	valid_1's rmse: 2.38476
# [1000]	training's rmse: 2.2332	valid_1's rmse: 2.33728
# [1100]	training's rmse: 2.19353	valid_1's rmse: 2.29246
# [1200]	training's rmse: 2.15968	valid_1's rmse: 2.25887
# [1300]	training's rmse: 2.12973	valid_1's rmse: 2.22565
# [1400]	training's rmse: 2.10137	valid_1's rmse: 2.20045
# [1500]	training's rmse: 2.07061	valid_1's rmse: 2.17098
# [1600]	training's rmse: 2.04426	valid_1's rmse: 2.14595
# [1700]	training's rmse: 2.02071	valid_1's rmse: 2.12309
# [1800]	training's rmse: 1.99884	valid_1's rmse: 2.10131
# [1900]	training's rmse: 1.9776	valid_1's rmse: 2.08305
# [2000]	training's rmse: 1.95741	valid_1's rmse: 2.06673
# [2100]	training's rmse: 1.93701	valid_1's rmse: 2.05063
# [2200]	training's rmse: 1.91858	valid_1's rmse: 2.04102
# [2300]	training's rmse: 1.90445	valid_1's rmse: 2.0339
# [2400]	training's rmse: 1.88971	valid_1's rmse: 2.0219
# [2500]	training's rmse: 1.87507	valid_1's rmse: 2.01608
# Early stopping, best iteration is:
# [2492]	training's rmse: 1.87604	valid_1's rmse: 2.01447
# Training until validation scores don't improve for 50 rounds
# [2500]	training's rmse: 1.87577	valid_1's rmse: 2.01426
# [2600]	training's rmse: 1.87024	valid_1's rmse: 2.01066
# [2700]	training's rmse: 1.86463	valid_1's rmse: 2.0062
# [2800]	training's rmse: 1.85875	valid_1's rmse: 2.00246
# [2900]	training's rmse: 1.85365	valid_1's rmse: 1.99822
# [3000]	training's rmse: 1.84776	valid_1's rmse: 1.99436
# [3100]	training's rmse: 1.84214	valid_1's rmse: 1.99267
# [3200]	training's rmse: 1.8372	valid_1's rmse: 1.9911
# [3300]	training's rmse: 1.83262	valid_1's rmse: 1.98872
# [3400]	training's rmse: 1.82782	valid_1's rmse: 1.98667
# [3500]	training's rmse: 1.82309	valid_1's rmse: 1.98308
# [3600]	training's rmse: 1.8182	valid_1's rmse: 1.98109
# [3700]	training's rmse: 1.81384	valid_1's rmse: 1.97863
# [3800]	training's rmse: 1.8097	valid_1's rmse: 1.97625
# [3900]	training's rmse: 1.80528	valid_1's rmse: 1.97423
# [4000]	training's rmse: 1.80073	valid_1's rmse: 1.97141
# [4100]	training's rmse: 1.79639	valid_1's rmse: 1.96906
# [4200]	training's rmse: 1.7921	valid_1's rmse: 1.96724
# [4300]	training's rmse: 1.78781	valid_1's rmse: 1.96461
# [4400]	training's rmse: 1.78379	valid_1's rmse: 1.96213
# [4500]	training's rmse: 1.77968	valid_1's rmse: 1.96015
# [4600]	training's rmse: 1.77539	valid_1's rmse: 1.95734
# [4700]	training's rmse: 1.77108	valid_1's rmse: 1.95511
# Early stopping, best iteration is:
# [4711]	training's rmse: 1.77068	valid_1's rmse: 1.95471
# 1.9547055097301853
# 2
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.35136	valid_1's rmse: 7.236
# [200]	training's rmse: 4.24131	valid_1's rmse: 4.33775
# [300]	training's rmse: 3.1349	valid_1's rmse: 3.27274
# [400]	training's rmse: 2.74237	valid_1's rmse: 2.87082
# [500]	training's rmse: 2.54971	valid_1's rmse: 2.65596
# [600]	training's rmse: 2.45932	valid_1's rmse: 2.55148
# [700]	training's rmse: 2.3925	valid_1's rmse: 2.48026
# [800]	training's rmse: 2.33432	valid_1's rmse: 2.42493
# [900]	training's rmse: 2.28698	valid_1's rmse: 2.37542
# [1000]	training's rmse: 2.24595	valid_1's rmse: 2.33375
# [1100]	training's rmse: 2.20504	valid_1's rmse: 2.28477
# [1200]	training's rmse: 2.16984	valid_1's rmse: 2.24656
# [1300]	training's rmse: 2.13507	valid_1's rmse: 2.21018
# [1400]	training's rmse: 2.10651	valid_1's rmse: 2.18451
# [1500]	training's rmse: 2.07802	valid_1's rmse: 2.15956
# [1600]	training's rmse: 2.05423	valid_1's rmse: 2.1387
# [1700]	training's rmse: 2.03015	valid_1's rmse: 2.11808
# [1800]	training's rmse: 2.00775	valid_1's rmse: 2.10006
# [1900]	training's rmse: 1.98683	valid_1's rmse: 2.07981
# [2000]	training's rmse: 1.96446	valid_1's rmse: 2.05999
# [2100]	training's rmse: 1.94553	valid_1's rmse: 2.04663
# [2200]	training's rmse: 1.92756	valid_1's rmse: 2.03227
# [2300]	training's rmse: 1.9094	valid_1's rmse: 2.02379
# [2400]	training's rmse: 1.89251	valid_1's rmse: 2.01108
# [2500]	training's rmse: 1.87668	valid_1's rmse: 2.0019
# [2600]	training's rmse: 1.8619	valid_1's rmse: 1.99323
# [2700]	training's rmse: 1.8467	valid_1's rmse: 1.97752
# [2800]	training's rmse: 1.833	valid_1's rmse: 1.97425
# Early stopping, best iteration is:
# [2760]	training's rmse: 1.83884	valid_1's rmse: 1.9725
# Training until validation scores don't improve for 50 rounds
# [2800]	training's rmse: 1.83693	valid_1's rmse: 1.97152
# [2900]	training's rmse: 1.83233	valid_1's rmse: 1.96983
# [3000]	training's rmse: 1.82764	valid_1's rmse: 1.96789
# [3100]	training's rmse: 1.8226	valid_1's rmse: 1.9658
# [3200]	training's rmse: 1.81815	valid_1's rmse: 1.96488
# [3300]	training's rmse: 1.81318	valid_1's rmse: 1.96342
# [3400]	training's rmse: 1.80843	valid_1's rmse: 1.95975
# [3500]	training's rmse: 1.80426	valid_1's rmse: 1.95733
# [3600]	training's rmse: 1.79932	valid_1's rmse: 1.95686
# Early stopping, best iteration is:
# [3553]	training's rmse: 1.80138	valid_1's rmse: 1.95673
# 1.953438214842616
# 3
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.22799	valid_1's rmse: 7.0949
# [200]	training's rmse: 4.04804	valid_1's rmse: 4.09673
# [300]	training's rmse: 2.97366	valid_1's rmse: 3.04631
# [400]	training's rmse: 2.63135	valid_1's rmse: 2.68389
# [500]	training's rmse: 2.48509	valid_1's rmse: 2.52763
# [600]	training's rmse: 2.39671	valid_1's rmse: 2.42962
# [700]	training's rmse: 2.33285	valid_1's rmse: 2.36001
# [800]	training's rmse: 2.28115	valid_1's rmse: 2.30532
# [900]	training's rmse: 2.24103	valid_1's rmse: 2.26627
# [1000]	training's rmse: 2.19924	valid_1's rmse: 2.22501
# [1100]	training's rmse: 2.16703	valid_1's rmse: 2.19666
# [1200]	training's rmse: 2.13264	valid_1's rmse: 2.16762
# [1300]	training's rmse: 2.10631	valid_1's rmse: 2.14142
# [1400]	training's rmse: 2.07985	valid_1's rmse: 2.11476
# [1500]	training's rmse: 2.05684	valid_1's rmse: 2.09892
# [1600]	training's rmse: 2.03518	valid_1's rmse: 2.0837
# [1700]	training's rmse: 2.01066	valid_1's rmse: 2.06351
# [1800]	training's rmse: 1.99327	valid_1's rmse: 2.04833
# [1900]	training's rmse: 1.97211	valid_1's rmse: 2.03255
# [2000]	training's rmse: 1.95471	valid_1's rmse: 2.017
# [2100]	training's rmse: 1.93924	valid_1's rmse: 2.00189
# [2200]	training's rmse: 1.92094	valid_1's rmse: 1.99461
# [2300]	training's rmse: 1.90561	valid_1's rmse: 1.98318
# [2400]	training's rmse: 1.89047	valid_1's rmse: 1.97392
# [2500]	training's rmse: 1.87612	valid_1's rmse: 1.9626
# [2600]	training's rmse: 1.86241	valid_1's rmse: 1.9587
# [2700]	training's rmse: 1.84889	valid_1's rmse: 1.95181
# [2800]	training's rmse: 1.83698	valid_1's rmse: 1.94147
# [2900]	training's rmse: 1.82457	valid_1's rmse: 1.92944
# Early stopping, best iteration is:
# [2940]	training's rmse: 1.81886	valid_1's rmse: 1.9271
# Training until validation scores don't improve for 50 rounds
# [3000]	training's rmse: 1.81633	valid_1's rmse: 1.92615
# [3100]	training's rmse: 1.81113	valid_1's rmse: 1.92517
# Early stopping, best iteration is:
# [3074]	training's rmse: 1.81287	valid_1's rmse: 1.92451
# 1.9424033073648492
# RMSE Fold-4 : 1.9424033073648492
# None
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 6.97265	valid_1's rmse: 6.91192
# [200]	training's rmse: 4.03992	valid_1's rmse: 3.80234
# [300]	training's rmse: 3.07857	valid_1's rmse: 2.81846
# [400]	training's rmse: 2.73532	valid_1's rmse: 2.53498
# [500]	training's rmse: 2.56876	valid_1's rmse: 2.43292
# [600]	training's rmse: 2.47611	valid_1's rmse: 2.39136
# [700]	training's rmse: 2.40255	valid_1's rmse: 2.36104
# [800]	training's rmse: 2.3504	valid_1's rmse: 2.33448
# [900]	training's rmse: 2.29911	valid_1's rmse: 2.32252
# [1000]	training's rmse: 2.25932	valid_1's rmse: 2.31704
# [1100]	training's rmse: 2.22094	valid_1's rmse: 2.30505
# [1200]	training's rmse: 2.18643	valid_1's rmse: 2.28778
# [1300]	training's rmse: 2.155	valid_1's rmse: 2.27839
# [1400]	training's rmse: 2.12507	valid_1's rmse: 2.26898
# [1500]	training's rmse: 2.09623	valid_1's rmse: 2.26443
# Early stopping, best iteration is:
# [1472]	training's rmse: 2.10497	valid_1's rmse: 2.26085
# Training until validation scores don't improve for 50 rounds
# [1500]	training's rmse: 2.1017	valid_1's rmse: 2.25929
# [1600]	training's rmse: 2.09036	valid_1's rmse: 2.25325
# [1700]	training's rmse: 2.0805	valid_1's rmse: 2.25087
# [1800]	training's rmse: 2.06988	valid_1's rmse: 2.24602
# [1900]	training's rmse: 2.06119	valid_1's rmse: 2.24134
# [2000]	training's rmse: 2.05221	valid_1's rmse: 2.23661
# [2100]	training's rmse: 2.04376	valid_1's rmse: 2.23306
# [2200]	training's rmse: 2.03483	valid_1's rmse: 2.22953
# [2300]	training's rmse: 2.02689	valid_1's rmse: 2.22385
# [2400]	training's rmse: 2.01937	valid_1's rmse: 2.22075
# Early stopping, best iteration is:
# [2395]	training's rmse: 2.01965	valid_1's rmse: 2.22072
# 2.2207220768683675
# 2
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.33427	valid_1's rmse: 7.22822
# [200]	training's rmse: 4.27914	valid_1's rmse: 4.03584
# [300]	training's rmse: 3.13259	valid_1's rmse: 2.91022
# [400]	training's rmse: 2.76274	valid_1's rmse: 2.60886
# [500]	training's rmse: 2.60533	valid_1's rmse: 2.5079
# [600]	training's rmse: 2.50648	valid_1's rmse: 2.46081
# [700]	training's rmse: 2.43078	valid_1's rmse: 2.42073
# [800]	training's rmse: 2.36961	valid_1's rmse: 2.39083
# [900]	training's rmse: 2.31531	valid_1's rmse: 2.36948
# [1000]	training's rmse: 2.26412	valid_1's rmse: 2.34608
# [1100]	training's rmse: 2.22275	valid_1's rmse: 2.32059
# [1200]	training's rmse: 2.18566	valid_1's rmse: 2.30215
# [1300]	training's rmse: 2.14972	valid_1's rmse: 2.28578
# [1400]	training's rmse: 2.11779	valid_1's rmse: 2.27133
# Early stopping, best iteration is:
# [1392]	training's rmse: 2.11983	valid_1's rmse: 2.27029
# Training until validation scores don't improve for 50 rounds
# [1400]	training's rmse: 2.11899	valid_1's rmse: 2.26995
# [1500]	training's rmse: 2.10854	valid_1's rmse: 2.2661
# [1600]	training's rmse: 2.09843	valid_1's rmse: 2.26064
# [1700]	training's rmse: 2.08818	valid_1's rmse: 2.25584
# [1800]	training's rmse: 2.07864	valid_1's rmse: 2.25178
# [1900]	training's rmse: 2.06977	valid_1's rmse: 2.24694
# [2000]	training's rmse: 2.0616	valid_1's rmse: 2.24472
# [2100]	training's rmse: 2.0537	valid_1's rmse: 2.24108
# [2200]	training's rmse: 2.04562	valid_1's rmse: 2.23877
# Early stopping, best iteration is:
# [2238]	training's rmse: 2.04212	valid_1's rmse: 2.23737
# 2.2257444535660813
# 3
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 7.21054	valid_1's rmse: 7.09508
# [200]	training's rmse: 4.24506	valid_1's rmse: 4.06435
# [300]	training's rmse: 3.25898	valid_1's rmse: 3.06209
# [400]	training's rmse: 2.86866	valid_1's rmse: 2.73009
# [500]	training's rmse: 2.68306	valid_1's rmse: 2.61414
# [600]	training's rmse: 2.56161	valid_1's rmse: 2.54686
# [700]	training's rmse: 2.47276	valid_1's rmse: 2.49643
# [800]	training's rmse: 2.39945	valid_1's rmse: 2.45006
# [900]	training's rmse: 2.33824	valid_1's rmse: 2.42631
# [1000]	training's rmse: 2.29052	valid_1's rmse: 2.4033
# [1100]	training's rmse: 2.24737	valid_1's rmse: 2.37642
# [1200]	training's rmse: 2.20347	valid_1's rmse: 2.35624
# [1300]	training's rmse: 2.16806	valid_1's rmse: 2.34372
# [1400]	training's rmse: 2.137	valid_1's rmse: 2.3226
# [1500]	training's rmse: 2.10757	valid_1's rmse: 2.31748
# Early stopping, best iteration is:
# [1478]	training's rmse: 2.1144	valid_1's rmse: 2.31559
# Training until validation scores don't improve for 50 rounds
# [1500]	training's rmse: 2.11233	valid_1's rmse: 2.31425
# [1600]	training's rmse: 2.10161	valid_1's rmse: 2.3084
# [1700]	training's rmse: 2.09235	valid_1's rmse: 2.30384
# [1800]	training's rmse: 2.08327	valid_1's rmse: 2.29921
# [1900]	training's rmse: 2.07339	valid_1's rmse: 2.29412
# [2000]	training's rmse: 2.06532	valid_1's rmse: 2.28927
# [2100]	training's rmse: 2.05598	valid_1's rmse: 2.28588
# [2200]	training's rmse: 2.04762	valid_1's rmse: 2.2804
# [2300]	training's rmse: 2.03835	valid_1's rmse: 2.27441
# [2400]	training's rmse: 2.02966	valid_1's rmse: 2.27083
# [2500]	training's rmse: 2.02223	valid_1's rmse: 2.26807
# [2600]	training's rmse: 2.01403	valid_1's rmse: 2.26391
# [2700]	training's rmse: 2.0056	valid_1's rmse: 2.2595
# [2800]	training's rmse: 1.99799	valid_1's rmse: 2.25509
# [2900]	training's rmse: 1.9905	valid_1's rmse: 2.2519
# [3000]	training's rmse: 1.98384	valid_1's rmse: 2.25005
# [3100]	training's rmse: 1.97704	valid_1's rmse: 2.24587
# Early stopping, best iteration is:
# [3108]	training's rmse: 1.97662	valid_1's rmse: 2.24526
# 2.2307662059294873
# RMSE Fold-5 : 2.2307662059294873
# 2.175801200371677

# %%
print(score_list)
np.mean(score_list)
# Out:
# [2.146763389858425, 2.5020675803552264, 2.0570055183503952, 1.9424033073648492, 2.2307662059294873]
# 2.175801200371677

# %%
preds = np.mean(test_preds,axis=0)

# %%
sample_sub[target] = np.round(preds)
sample_sub.to_csv(sub_path+'\\base_cross_val.csv', index=False)

# %%
lgb = LGBMClassifier()

# %%
lgb.feature_importances_
